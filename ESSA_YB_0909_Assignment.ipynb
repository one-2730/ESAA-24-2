# %% [markdown]
# <a href="https://colab.research.google.com/github/one-2730/ESAA-24-2/blob/Assignment/ESSA_YB_0909_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #10 시각화
# ##1.개요
#
# 맷플롯립(Matplotlib)
# - 가장 많이 쓰이는 시각화 라이브러리
# - 직관적이지 못한 API, 부가적 속성까지 코딩해줘야 함
#
# 시본(Seaborn)
# - 맷플롯립을 기반으로 하지만, 상대적으로 쉬운 난이도
# - 판다스와 연동

# %% [markdown]
# ##2. 맷플롯립

# %%
import matplotlib.pyplot as plt

#x축 입력값 [1, 2, 3], y축 입력값 [2, 4, 6]
plt.plot([1, 2, 3], [2, 4, 6])

#선그래프 타이틀을 Hello plot으로 설정
plt.title("Hello plot")

#선 그래프를 출력
plt.show()

# %% [markdown]
# ###Figure & Axes
#
# **Figure**
# - 그림을 그리기 위한 캔버스
#
# **Axes**
# - 실제로 그림을 그리는 매서드들을 가짐

# %%
#plt.figure()는 주로 figure의 크기를 조절하는 데 사용됨
#아래는 figure 크기가 가로 10, 세로 4인 Figure 객체를 설정하고 반환함
plt.figure(figsize = (10, 4))

plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Hello plot")
plt.show()

# %%
figure = plt.figure(figsize = (10, 4))
print(type(figure))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
plt.figure(figsize = (4, 4), facecolor = "yellow")
plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Hello plot")

plt.show()

# %%
ax = plt.axes()
print(type(ax))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
##pyplot에서 설정된 Figure와 Axes 객체를 함께 가져오기
fig, ax = plt.subplots()
print("fig type:", type(fig), '\nax type:', type(ax))
# Out:
# fig type: <class 'matplotlib.figure.Figure'>
# ax type: <class 'matplotlib.axes._axes.Axes'>

# %%
fig, ax = plt.subplots(figsize = (4, 4))

#Axes 객체의 plot()을 이용하여 선 그래프를 그림
ax.plot([1, 2, 3], [2, 4, 6])

#Axes 객체의 set_title()을 이용하여 선 그래프 타이틀을 Hello plot으로 변경
ax.set_title('Hello plot')

plt.show()

# %% [markdown]
# ###여러개의 plot을 가지는 subplot들을 생성하기
#
# plt.subplots()
#   nrows, ncols, figsize

# %%
#아래는 두 개의 subplot, 즉 두개의 Axes를 생성하되 열 방향으로 두 개를 배치함
#또한 전체 크기가 가로 6, 세로 3인 Figure 생성
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (6, 3))

# %%
import numpy as np
import pandas as pd

#list
x_value = [1, 2, 3, 4]
y_value = [2, 4, 6, 8]

plt.plot(x_value, y_value)
plt.show()

# %%
#ndarray
x_value = np.array([1, 2, 3, 4])
y_value = np.array([2, 4, 6, 8])

plt.plot(x_value, y_value)
plt.show()

# %%
#DataFrame
df = pd.DataFrame([1, 2, 3, 4],
                  [2, 4, 6, 8])

plt.plot(df)
plt.show()

# %%
#color 인자를 green으로 설정하여 선의 색깔을 녹색으로 변경
plt.plot(x_value, y_value, color = 'green')

# %%
#더 다양하게 변화시키기 위해 API를 기반으로 시각화
plt.plot(
    x_value, y_value, color = 'red', marker = "o", linestyle = 'dashed', linewidth = 2, markersize = 12
)

# %% [markdown]
# ###축 명칭 설정, 축의 눈금값 회전, 범례 설정하기

# %%
plt.plot(
    x_value, y_value, color = 'red', marker = 'o', linestyle = 'dashed', linewidth = 2, markersize = 12
)

#x축과 y축의 이름을 텍스트로 할당하여 설정
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
#x 좌표 값을 0~99의 100개로 설정
x_value = np.arange(100)
#y 좌표 값은 개별 x좌표값을 2배로 해서 100개로 설정
y_value = 2 * x_value

plt.plot(x_value, y_value, color = 'green')
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
#x축 눈금 값을 90도 회전
plt.xticks(rotation = 90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
x_value = np.arange(100)
y_value = 2 * x_value

plt.plot(x_value, y_value, color = 'green')
plt.xlabel('x axis')
plt.ylabel('y axis')

#x축의 눈금 값을 np.arange(0, 100, 5)로 하여 0부터 99까지 5 스텝으로 20개를 표시하고 90도 회전
plt.xticks(ticks = np.arange(0, 100, 5), rotation = 90)
plt.show()

# %%
x_value = np.arange(100)
y_value01 = 2 * x_value
y_value02 = 4 * x_value

plt.plot(x_value, y_value01, color = 'green', label = 'green line')
plt.plot(x_value, y_value02, color = 'red', label = 'red line')

plt.xlabel('x axis')
plt.ylabel('y axis')

plt.legend()

plt.title('Hello plot')

plt.show()

# %%
x_value = np.arange(10)
y_value = 2 * x_value

plt.plot(x_value, y_value, color = 'red', marker = 'o', linestyle = 'dashed', label = 'red line')
plt.bar(x_value, y_value, color = 'green', label = 'bar plot')
plt.xlabel('x axis')
plt.xlabel('y axis')

plt.legend()

plt.title('Hello plot')

plt.show()

# %%
#Axes 객체 메서드 이용

figure = plt.figure()
ax = plt.axes()

ax.plot(x_value, y_value, color = 'red', marker = 'o', linestyle = 'dashed', label = 'red line')
ax.bar(x_value, y_value, color = 'green', label = 'bar plot')

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

ax.legend()

ax.set_title('Hello plot')

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (6, 3))

# %%
print('ax type:', type(ax))
print('ax[0] type:', type(ax[0]))
print('ax[1] type:', type(ax[1]))

#여러개의 subplots를 이용해서 시각화를 구현할 때는 개별 Axes 객체를 직접 이용해서 시각화를 구현해야 함
# Out:
# ax type: <class 'numpy.ndarray'>
# ax[0] type: <class 'matplotlib.axes._axes.Axes'>
# ax[1] type: <class 'matplotlib.axes._axes.Axes'>

# %%
import numpy as np

x_value_01 = np.arange(10)
x_value_02 = np.arange(20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

#figsize는 (6, 3)인 Figure와 2개의 Axes를 가지는 subplots를 반환
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (6, 3))

#개별 Axes 객체들을 각각 이용하여 선 그래프와 막대그래프를 그림
ax[0].plot(x_value_01, y_value_01, color = 'red', marker = 'o', linestyle = 'dashed', label = 'red line')
ax[1].bar(x_value_02, y_value_02, color = 'green', label = 'bar plot')
#개별 Axes 객체에 각각 x축의 레이블을 설정
ax[0].set_xlabel('ax[0] x axis')
ax[1].set_xlabel('ax[1] x axis')
#개별 Axes 객체에 각각 범례를 설정
ax[0].legend()
ax[1].legend()
#개별 Axes 객체에 각각 타이틀을 설정
ax[0].set_title('Hello line')
ax[1].set_title('Hello bar')

plt.show()

# %%
import numpy as np

x_value_01 = np.arange(10)
x_value_02 = np.arange(20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (6, 6))

ax[0][0].plot(x_value_01, y_value_01, color = 'red', marker = 'o', linestyle = 'dashed', label = 'red line')
ax[0][1].bar(x_value_02, y_value_02, color = 'green', label = 'green bar')
ax[1][0].plot(
    x_value_01, y_value_01, color = 'green', marker = 'o', linestyle = 'dashed', label = 'green line'
)
ax[1][1].bar(x_value_02, y_value_02, color = 'red', label = 'red bar')

ax[0][0].set_xlabel('ax[0][0] x axis')
ax[0][1].set_xlabel('ax[0][1] x axis')
ax[1][0].set_xlabel('ax[1][0] x axis')
ax[1][1].set_xlabel('ax[1][1] x axis')

ax[0][0].legend()
ax[0][1].legend()
ax[1][0].legend()
ax[1][1].legend()

plt.show()
